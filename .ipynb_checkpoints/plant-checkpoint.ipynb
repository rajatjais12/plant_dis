# %%
import numpy as np
import datetime
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random 
import pandas.util.testing as tm
import os
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from keras import backend as K
import pickle
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-de48e1460cfd> in <module>
#       1 import numpy as np
#       2 import datetime
# ----> 3 import tensorflow as tf
#       4
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
default_image_size=tuple((256, 256))
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
directory_root='PlantVillage'
image_list=[]
img_name=[]
list_img_filename=[]

# %%
for  dirname,dis,filenames in os.walk(directory_root):
    #list_img_array.append(dirname)
    for filename in filenames:
     
        if filename.endswith(".jpg") == True or filename.endswith(".JPG") == True:
            image_list.append(convert_image_to_array(os.path.join(dirname,filename)))
            img_name.append(dirname)
            list_img_filename.append(filename)

# %%
len(img_name)
# Out:
# 18859

# %%
len(image_list)
# Out:
# 18859

# %%
image_list[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-77b3b76f3f6a> in <module>
# ----> 1 image_list[0]
#
# NameError: name 'image_list' is not defined

# %%
img_name[2]
# Out:
# 'PlantVillage\\Pepper__bell___Bacterial_spot'

# %%
data={'X':image_list,'Y':img_name}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                                                        X  \
# 0      [[[97.0, 94.0, 109.0], [91.0, 88.0, 103.0], [1...
# 1      [[[148.0, 125.0, 139.0], [150.0, 127.0, 141.0]...
# 2      [[[159.0, 140.0, 155.0], [123.0, 106.0, 120.0]...
# 3      [[[11.0, 13.0, 7.0], [11.0, 12.0, 8.0], [10.0,...
# 4      [[[169.0, 168.0, 178.0], [168.0, 167.0, 177.0]...
# ...                                                  ...
# 18854  [[[130.0, 122.0, 129.0], [120.0, 112.0, 119.0]...
# 18855  [[[119.0, 120.0, 118.0], [118.0, 119.0, 117.0]...
# 18856  [[[140.0, 136.0, 147.0], [140.0, 136.0, 147.0]...
# 18857  [[[140.0, 141.0, 139.0], [140.0, 141.0, 139.0]...
# 18858  [[[82.0, 80.0, 80.0], [79.0, 77.0, 77.0], [77....
#
#                                                        Y
# 0             PlantVillage\Pepper__bell___Bacterial_spot
# 1             PlantVillage\Pepper__bell___Bacterial_spot
# 2             PlantVillage\Pepper__bell___Bacterial_spot
# ...

# %%
df.to_csv('x_y_csv.csv', sep='\t', encoding='utf-8', header='true')

# %%
df.head()
# Out:
#                                                    X  \
# 0  [[[97.0, 94.0, 109.0], [91.0, 88.0, 103.0], [1...
# 1  [[[148.0, 125.0, 139.0], [150.0, 127.0, 141.0]...
# 2  [[[159.0, 140.0, 155.0], [123.0, 106.0, 120.0]...
# 3  [[[11.0, 13.0, 7.0], [11.0, 12.0, 8.0], [10.0,...
# 4  [[[169.0, 168.0, 178.0], [168.0, 167.0, 177.0]...
#
#                                             Y
# 0  PlantVillage\Pepper__bell___Bacterial_spot
# 1  PlantVillage\Pepper__bell___Bacterial_spot
# 2  PlantVillage\Pepper__bell___Bacterial_spot
# 3  PlantVillage\Pepper__bell___Bacterial_spot
# 4  PlantVillage\Pepper__bell___Bacterial_spot

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
label_binarizer = LabelBinarizer()
labels = label_binarizer.fit_transform(img_name)
pickle.dump(label_binarizer,open('label_trns.pkl','wb'))
n_classes1 = len(label_binarizer.classes_)

# %%
data2={'X':image_list,'Y':img_name,'Y_l':labels}

# %%
print(len(image_list))
print(len(img_name))
b=len(labels)
# Out:
# 18859
# 18859

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
np_img=[]

for i in range(0,b):
    np_img.append(np.array(image_list[i]))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image_list[1]/230)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\rajat\anaconda3\envs\tens2\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# c:\users\rajat\anaconda3\envs\tens2\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# c:\users\rajat\anaconda3\envs\tens2\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# ...
