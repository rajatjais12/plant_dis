# %%
import pickle
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import random 
import os
import pandas as pd
import numpy as np
import matplotlib.image as mpimg

# %%
default_image_size=tuple((32, 32))
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)  
            
            return  img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpllimg

# %%
img=mpllimg.imread('PlantVillage\\Pepper__bell___Bacterial_spot\\1e1ee82b-592b-4158-a48b-347084647492___NREC_B.Spot 9046.JPG')
img_plot = plt.imshow(img/255)
plt.show()

# %%
img=mpllimg.imread('PlantVillage\\Tomato_healthy\\0a31e630-0d98-416b-b0e4-88a88aad1dc5___RS_HL 9653.JPG')
img_plot = plt.imshow(img/255)
plt.show()

# %%
img=mpllimg.imread('PlantVillage\\Tomato_Late_blight\\1a473cad-42fc-48ca-963c-d438fbca928f___RS_Late.B 5418.JPG')
img_plot = plt.imshow(img/255)
plt.show()

# %%
img=mpllimg.imread('PlantVillage\\Tomato_Leaf_Mold\\9a067a91-70b3-4801-9a25-bb86f8d0691e___Crnl_L.Mold 8867.JPG')
img_plot = plt.imshow(img/255)
plt.show()
